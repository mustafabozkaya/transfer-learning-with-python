# %%
#https://medium.com/unpackai/how-to-use-kaggle-datasets-in-google-colab-f9b2e4b5767c

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install kaggle

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
#@title Download kaggle dataset after rules aggreed
#!kaggle competitions download -c dogs-vs-cats

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/kaggledatasets/"

# %%
#%cd drive/MyDrive/kaggledatasets/

# %%
# %cd /content/
# Out:
# /content

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
DATA_DIR = './githupfolder/'

# load repo with data if it is not exists
if not os.path.exists(DATA_DIR):
    print('Loading data...')
    os.system('git clone https://github.com/dipanjanS/hands-on-transfer-learning-with-python ./githupfolder')
    print('Done!')
# Out:
# Loading data...
# Done!

# %%
# !unzip "/content/drive/MyDrive/kaggledatasets/train.zip" -d "/content/githupfolder/notebooks/datasets"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5499.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.55.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.550.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5500.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5501.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5502.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5503.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5504.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5505.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5506.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5507.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5508.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5509.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.551.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5510.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5511.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5512.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5513.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5514.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5515.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5516.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5517.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5518.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5519.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.552.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5520.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5521.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5522.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5523.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5524.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5525.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5526.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5527.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5528.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5529.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.553.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5530.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5531.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5532.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5533.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5534.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5535.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5536.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5537.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5538.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5539.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.554.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5540.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5541.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5542.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5543.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5544.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5545.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5546.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5547.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5548.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5549.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.555.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5550.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5551.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5552.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5553.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5554.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5555.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5556.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5557.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5558.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5559.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.556.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5560.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5561.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5562.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5563.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5564.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5565.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5566.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5567.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5568.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5569.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.557.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5570.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5571.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5572.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5573.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5574.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5575.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5576.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5577.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5578.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5579.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.558.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5580.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5581.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5582.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5583.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5584.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5585.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5586.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5587.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5588.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5589.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.559.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5590.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5591.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5592.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5593.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5594.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5595.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5596.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5597.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5598.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5599.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.56.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.560.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5600.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5601.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5602.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5603.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5604.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5605.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5606.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5607.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5608.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5609.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.561.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5610.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5611.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5612.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5613.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5614.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5615.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5616.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5617.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5618.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5619.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.562.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5620.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5621.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5622.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5623.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5624.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5625.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5626.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5627.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5628.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5629.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.563.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5630.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5631.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5632.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5633.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5634.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5635.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5636.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5637.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5638.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5639.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.564.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5640.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5641.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5642.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5643.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5644.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5645.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5646.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5647.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5648.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5649.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.565.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5650.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5651.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5652.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5653.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5654.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5655.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5656.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5657.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5658.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5659.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.566.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5660.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5661.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5662.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5663.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5664.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5665.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5666.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5667.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5668.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5669.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.567.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5670.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5671.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5672.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5673.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5674.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5675.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5676.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5677.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5678.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5679.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.568.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5680.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5681.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5682.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5683.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5684.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5685.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5686.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5687.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5688.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5689.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.569.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5690.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5691.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5692.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5693.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5694.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5695.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5696.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5697.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5698.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5699.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.57.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.570.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5700.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5701.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5702.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5703.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5704.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5705.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5706.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5707.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5708.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5709.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.571.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5710.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5711.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5712.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5713.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5714.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5715.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5716.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5717.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5718.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5719.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.572.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5720.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5721.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5722.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5723.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5724.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5725.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5726.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5727.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5728.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5729.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.573.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5730.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5731.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5732.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5733.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5734.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5735.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5736.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5737.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5738.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5739.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.574.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5740.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5741.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5742.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5743.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5744.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5745.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5746.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5747.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5748.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5749.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.575.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5750.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5751.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5752.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5753.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5754.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5755.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5756.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5757.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5758.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5759.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.576.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5760.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5761.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5762.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5763.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5764.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5765.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5766.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5767.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5768.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5769.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.577.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5770.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5771.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5772.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5773.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5774.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5775.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5776.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5777.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5778.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5779.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.578.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5780.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5781.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5782.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5783.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5784.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5785.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5786.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5787.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5788.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5789.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.579.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5790.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5791.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5792.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5793.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5794.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5795.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5796.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5797.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5798.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5799.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.58.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.580.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5800.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5801.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5802.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5803.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5804.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5805.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5806.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5807.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5808.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5809.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.581.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5810.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5811.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5812.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5813.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5814.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5815.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5816.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5817.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5818.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5819.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.582.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5820.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5821.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5822.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5823.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5824.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5825.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5826.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5827.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5828.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5829.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.583.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5830.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5831.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5832.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5833.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5834.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5835.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5836.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5837.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5838.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5839.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.584.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5840.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5841.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5842.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5843.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5844.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5845.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5846.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5847.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5848.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5849.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.585.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5850.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5851.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5852.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5853.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5854.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5855.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5856.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5857.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5858.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5859.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.586.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5860.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5861.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5862.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5863.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5864.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5865.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5866.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5867.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5868.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5869.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.587.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5870.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5871.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5872.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5873.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5874.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5875.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5876.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5877.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5878.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5879.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.588.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5880.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5881.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5882.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5883.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5884.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5885.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5886.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5887.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5888.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5889.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.589.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5890.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5891.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5892.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5893.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5894.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5895.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5896.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5897.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5898.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5899.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.59.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.590.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5900.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5901.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5902.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5903.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5904.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5905.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5906.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5907.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5908.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5909.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.591.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5910.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5911.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5912.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5913.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5914.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5915.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5916.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5917.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5918.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5919.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.592.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5920.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5921.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5922.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5923.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5924.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5925.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5926.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5927.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5928.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5929.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.593.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5930.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5931.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5932.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5933.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5934.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5935.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5936.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5937.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5938.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5939.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.594.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5940.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5941.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5942.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5943.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5944.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5945.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5946.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5947.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5948.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5949.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.595.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5950.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5951.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5952.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5953.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5954.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5955.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5956.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5957.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5958.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5959.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.596.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5960.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5961.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5962.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5963.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5964.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5965.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5966.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5967.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5968.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5969.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.597.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5970.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5971.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5972.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5973.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5974.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5975.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5976.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5977.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5978.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5979.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.598.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5980.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5981.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5982.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5983.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5984.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5985.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5986.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5987.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5988.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5989.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.599.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5990.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5991.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5992.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5993.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5994.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5995.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5996.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5997.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5998.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.5999.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.60.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.600.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6000.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6001.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6002.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6003.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6004.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6005.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6006.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6007.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6008.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6009.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.601.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6010.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6011.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6012.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6013.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6014.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6015.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6016.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6017.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6018.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6019.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.602.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6020.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6021.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6022.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6023.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6024.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6025.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6026.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6027.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6028.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6029.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.603.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6030.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6031.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6032.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6033.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6034.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6035.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6036.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6037.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6038.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6039.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.604.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6040.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6041.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6042.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6043.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6044.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6045.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6046.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6047.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6048.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6049.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.605.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6050.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6051.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6052.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6053.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6054.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6055.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6056.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6057.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6058.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6059.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.606.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6060.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6061.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6062.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6063.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6064.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6065.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6066.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6067.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6068.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6069.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.607.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6070.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6071.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6072.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.6073.jpg
# ...
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9807.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9808.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9809.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.981.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9810.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9811.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9812.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9813.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9814.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9815.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9816.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9817.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9818.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9819.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.982.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9820.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9821.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9822.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9823.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9824.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9825.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9826.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9827.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9828.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9829.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.983.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9830.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9831.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9832.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9833.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9834.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9835.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9836.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9837.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9838.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9839.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.984.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9840.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9841.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9842.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9843.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9844.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9845.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9846.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9847.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9848.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9849.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.985.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9850.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9851.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9852.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9853.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9854.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9855.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9856.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9857.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9858.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9859.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.986.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9860.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9861.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9862.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9863.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9864.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9865.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9866.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9867.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9868.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9869.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.987.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9870.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9871.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9872.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9873.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9874.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9875.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9876.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9877.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9878.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9879.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.988.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9880.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9881.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9882.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9883.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9884.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9885.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9886.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9887.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9888.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9889.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.989.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9890.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9891.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9892.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9893.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9894.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9895.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9896.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9897.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9898.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9899.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.99.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.990.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9900.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9901.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9902.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9903.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9904.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9905.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9906.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9907.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9908.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9909.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.991.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9910.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9911.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9912.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9913.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9914.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9915.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9916.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9917.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9918.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9919.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.992.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9920.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9921.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9922.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9923.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9924.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9925.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9926.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9927.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9928.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9929.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.993.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9930.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9931.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9932.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9933.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9934.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9935.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9936.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9937.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9938.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9939.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.994.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9940.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9941.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9942.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9943.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9944.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9945.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9946.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9947.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9948.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9949.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.995.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9950.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9951.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9952.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9953.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9954.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9955.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9956.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9957.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9958.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9959.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.996.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9960.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9961.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9962.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9963.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9964.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9965.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9966.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9967.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9968.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9969.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.997.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9970.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9971.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9972.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9973.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9974.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9975.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9976.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9977.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9978.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9979.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.998.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9980.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9981.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9982.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9983.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9984.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9985.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9986.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9987.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9988.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9989.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.999.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9990.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9991.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9992.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9993.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9994.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9995.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9996.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9997.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9998.jpg
#   inflating: /content/githupfolder/notebooks/datasets/train/dog.9999.jpg

# %% [markdown]
# # Data loader processing

# %%
# %cd /
# Out:
# /

# %%
# %cd content/githupfolder/notebooks/Ch05\ -\ Unleash\ the\ Power\ of\ Transfer\ Learning
# Out:
# /content/githupfolder/notebooks/Ch05 - Unleash the Power of Transfer Learning

# %%
import glob
import numpy as np
import os
import shutil
from utils import log_progress
import cv2 as cv
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"]=(18,8)
# %matplotlib inline
np.random.seed(42)

# %%
# %pwd
# Out:
# '/content/githupfolder/notebooks/Ch05 - Unleash the Power of Transfer Learning'

# %%
files = np.array(glob.glob('../datasets/train/*'))
files.shape
# Out:
# (25000,)

# %%
files[:5]
# Out:
# array(['../datasets/train/dog.51.jpg', '../datasets/train/dog.822.jpg',
#        '../datasets/train/cat.11024.jpg',
#        '../datasets/train/cat.7047.jpg', '../datasets/train/cat.8557.jpg'],
#       dtype='<U31')

# %%
cat_files = [fn for fn in files if 'cat.' in fn]
dog_files = [fn for fn in files if 'dog.' in fn]
len(cat_files), len(dog_files)
# Out:
# (12500, 12500)

# %%
img_=dog_files[1000]

# %%
#cv.imshow("cat image",cat_files[21])
img=cv.imread(img_)
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=247x207 at 0x7F7B4205AB10>

# %%
cat_train = np.random.choice(cat_files, size=1500, replace=False)
dog_train = np.random.choice(dog_files, size=1500, replace=False)
cat_files = list(set(cat_files) - set(cat_train))
dog_files = list(set(dog_files) - set(dog_train))

cat_val = np.random.choice(cat_files, size=500, replace=False)
dog_val = np.random.choice(dog_files, size=500, replace=False)
cat_files = list(set(cat_files) - set(cat_val))
dog_files = list(set(dog_files) - set(dog_val))

cat_test = np.random.choice(cat_files, size=500, replace=False)
dog_test = np.random.choice(dog_files, size=500, replace=False)

print('Cat datasets:', cat_train.shape, cat_val.shape, cat_test.shape)
print('Dog datasets:', dog_train.shape, dog_val.shape, dog_test.shape)
# Out:
# Cat datasets: (1500,) (500,) (500,)
# Dog datasets: (1500,) (500,) (500,)

# %%
len(cat_files), len(dog_files)
# Out:
# (10500, 10500)

# %%
cat_train[:2],dog_train[:2]
# Out:
# (array(['../datasets/train/cat.2541.jpg', '../datasets/train/cat.6252.jpg'],
#        dtype='<U31'),
#  array(['../datasets/train/dog.4028.jpg', '../datasets/train/dog.8123.jpg'],
#        dtype='<U31'))

# %%
train_files = np.concatenate([cat_train, dog_train])
validate_files = np.concatenate([cat_val, dog_val])
test_files = np.concatenate([cat_test, dog_test])

# %%
print('train datasets:', train_files.shape, validate_files.shape, test_files.shape)
# Out:
# train datasets: (3000,) (1000,) (1000,)

# %%
data_dir="/content/githupfolder/notebooks/datasets/dog_cat"
if not os.path.exists(data_dir):
  os.mkdir(data_dir)

train_dir = "train_data"
val_dir = "validation_data"
test_dir = "test_data"

# %%
os.chdir("/content/githupfolder/notebooks/Ch05 - Unleash the Power of Transfer Learning/")

# %%
os.mkdir(os.path.join(data_dir,train_dir)) if not os.path.exists(os.path.join(data_dir,train_dir)) else None
os.mkdir(os.path.join(data_dir,val_dir)) if not os.path.exists(os.path.join(data_dir,val_dir)) else None
os.mkdir(os.path.join(data_dir,test_dir)) if not os.path.exists(os.path.join(data_dir,test_dir)) else None

for fn in log_progress(train_files, name='Training Images'):
    shutil.copy(fn, os.path.join(data_dir,train_dir))

for fn in log_progress(validate_files, name='Validation Images'):
    shutil.copy(fn, os.path.join(data_dir,val_dir) )
    
for fn in log_progress(test_files, name='Test Images'):
    shutil.copy(fn, os.path.join(data_dir,test_dir) )
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=3000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1000)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1000)))

# %%
# %ls
# Out:
# 'Basic CNN Model.ipynb'               model_evaluation_utils.py
# 'CNN with Image Augmentation.ipynb'  'Model Performance Evaluations.ipynb'
# 'CNN with Transfer Learning.ipynb'    __pycache__/
# 'Datasets Builder.ipynb'              utils.py

# %%
import pandas as pd
train_=pd.DataFrame([image_f for image_f in os.listdir(os.path.join(data_dir,train_dir))],columns=["img_file"])

# %%
train_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   img_file  3000 non-null   object
# dtypes: object(1)
# memory usage: 23.6+ KB

# %% [markdown]
# # İmage Preparing and EDA

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
 IMG_DIM = (150, 150)

train_files = glob.glob(str(os.path.join(data_dir,train_dir))+'/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[7].split(".")[0].strip() for fn in train_files]

validation_files =  glob.glob(str(os.path.join(data_dir,val_dir))+'/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[7].split(".")[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape,
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
#(str(os.path.join(data_dir,train_dir))+'/*')

# %% [markdown]
# ## İmage proprocessing , Scalling and Label encoder

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255
train_imgs.shape
# Out:
# (3000, 150, 150, 3)

# %%
print(train_imgs[0].shape)
array_to_img(train_imgs[0])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F7B91E6EF50>

# %%
# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog'] [0 0 1 1 1 1 1 0 0 1]

# %% [markdown]
# ## Sample image Hist Plotting

# %%
plt.imshow(train_imgs_scaled[0])

# %%
# convert the image to grayscale and create a histogram
cv_img=train_imgs[0]
cv_img = cv.cvtColor(cv_img, cv.COLOR_BGR2GRAY)
cv2_imshow(cv_img)
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F7B922EA350>

# %%
hist = cv.calcHist([cv_img], [0], None, [256], [0, 256])
plt.figure(figsize=(18,8))
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(hist)
plt.xlim([0, 256])
# Out:
# (0.0, 256.0)

# %% [markdown]
# ## Computing a Flattened Color Histogram using Python and OpenCV

# %%
# grab the image channels, initialize the tuple of colors,
# the figure and the flattened feature vector
cv_img=train_imgs[0]
chans = cv.split(cv_img)
colors = ("b", "g", "r")
plt.figure(figsize=(18,8))
plt.title("'Flattened' Color Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
features = []
# loop over the image channels
for (chan, color) in zip(chans, colors):
	# create a histogram for the current channel and
	# concatenate the resulting histograms for each
	# channel
	hist = cv.calcHist([chan], [0], None, [256], [0, 256])
	features.extend(hist)
	# plot the histogram
	plt.plot(hist, color = color)
	plt.xlim([0, 256])
 
plt.legend(colors)
# here we are simply showing the dimensionality of the
# flattened color histogram 256 bins for each channel
# x 3 channels = 768 total values -- in practice, we would
# normally not use 256 bins for each channel, a choice
# between 32-96 bins are normally used, but this tends
# to be application dependent
print ("flattened feature vector size: %{0} ".format(np.array(features).flatten().shape))
# Out:
# flattened feature vector size: %(768,)

# %% [markdown]
# # **Transfer learning**

# %%
batch_size = 30
num_classes = 2
epochs = 15
input_shape = (150, 150, 3)

# %% [markdown]
# ### VGG_16 full model

# %%
from keras.applications import vgg16
from keras.models import Model
import keras
import tensorflow as tf


vggfull= vgg16.VGG16(include_top=True, weights='imagenet')

vggfull.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 24s 0us/step
# 553476096/553467096 [==============================] - 24s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import  plot_model
data_dir="/content/githupfolder/notebooks/models"
if not os.path.exists(data_dir):
  os.mkdir(data_dir)
plot_model(vggfull,to_file="../models/VGG16Fullmodel.png",show_shapes=True, 
                 show_layer_names=True, rankdir='TB',dpi=90)

# %% [markdown]
# ## VGG base Model

# %%
from keras.applications import vgg16
from keras.models import Model
import keras
import tensorflow as tf


vgg_base = vgg16.VGG16(include_top=False, weights='imagenet', 
                                     input_shape=input_shape)
vgg_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step
# 58900480/58889256 [==============================] - 2s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(vgg_base,to_file="../models/Transferlearning_VGG16base.png",show_shapes=True, 
                 show_layer_names=True, rankdir='TB',dpi=90)

# %% [markdown]
# ## import Flatten layer to VGG base model

# %%
output = vgg_base.layers[-1].output
output = keras.layers.Flatten()(output)

vgg_model = Model(vgg_base.input, output)
vgg_model.trainable = False

for layer in vgg_model.layers:
    layer.trainable = False

vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
plot_model(vgg_model,to_file="../models/Transferlearning_VGG16base_addFlatten.png",show_shapes=True, 
                 show_layer_names=True, rankdir='TB',dpi=90)

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                         Layer Type  ... Layer Trainable
# 0   <keras.engine.input_layer.InputLayer object at 0x7f7b8a9467d0>  ...           False
# 1     <keras.layers.convolutional.Conv2D object at 0x7f7b8a97eed0>  ...           False
# 2     <keras.layers.convolutional.Conv2D object at 0x7f7b8a91c990>  ...           False
# 3     <keras.layers.pooling.MaxPooling2D object at 0x7f7b8a8a1cd0>  ...           False
# 4     <keras.layers.convolutional.Conv2D object at 0x7f7b800e8510>  ...           False
# 5     <keras.layers.convolutional.Conv2D object at 0x7f7b800f2150>  ...           False
# 6     <keras.layers.pooling.MaxPooling2D object at 0x7f7b800e8110>  ...           False
# 7     <keras.layers.convolutional.Conv2D object at 0x7f7b800f4c90>  ...           False
# 8     <keras.layers.convolutional.Conv2D object at 0x7f7b80102350>  ...           False
# 9     <keras.layers.convolutional.Conv2D object at 0x7f7b80107c10>  ...           False
# 10    <keras.layers.pooling.MaxPooling2D object at 0x7f7b800f4fd0>  ...           False
# 11    <keras.layers.convolutional.Conv2D object at 0x7f7b8010f550>  ...           False
# 12    <keras.layers.convolutional.Conv2D object at 0x7f7b80115250>  ...           False
# 13    <keras.layers.convolutional.Conv2D object at 0x7f7b8010f0d0>  ...           False
# 14    <keras.layers.pooling.MaxPooling2D object at 0x7f7b8009f690>  ...           False
# 15    <keras.layers.convolutional.Conv2D object at 0x7f7b800a2d50>  ...           False
# 16    <keras.layers.convolutional.Conv2D object at 0x7f7b800a8850>  ...           False
# 17    <keras.layers.convolutional.Conv2D object at 0x7f7b8009c810>  ...           False
# 18    <keras.layers.pooling.MaxPooling2D object at 0x7f7b800b1f50>  ...           False
# 19            <keras.layers.core.Flatten object at 0x7f7b8002a150>  ...           False
#
# [20 rows x 3 columns]

# %%
print("Trainable layers:", len(vgg_model.trainable_weights))
# Out:
# Trainable layers: 0

# %%
print("non-Trainable layers:", len(vgg_model.non_trainable_weights))
# Out:
# non-Trainable layers: 26

# %%
#train_imgs_scaled[:1].squeeze().shape
# Out:
# (150, 150, 3)

# %% [markdown]
# ## Feature Extructure from VGG base model

# %%
bottleneck_feature_vggBase = vgg_base.predict(train_imgs_scaled[:1])
print(bottleneck_feature_vggBase.shape)
print(train_imgs_scaled[0:1].shape)
plt.imshow(bottleneck_feature_vggBase[0][:,:,51])
# Out:
# (1, 4, 4, 512)
# (1, 150, 150, 3)

# %%
def get_bottleneck_features(model, input_imgs):
    
    features = model.predict(input_imgs, verbose=0)
    return features

# %%
train_features_vggmodel = get_bottleneck_features(vgg_model, train_imgs_scaled)
validation_features_vggmodel = get_bottleneck_features(vgg_model, validation_imgs_scaled)

print('Train Bottleneck Features from vgg_model :', train_features_vggmodel.shape, 
      '\tValidation Bottleneck Features from vgg_model:', validation_features_vggmodel.shape)
# Out:
# Train Bottleneck Features from vgg_model : (3000, 8192) 	Validation Bottleneck Features from vgg_model: (1000, 8192)

# %%
vgg_base.input_shape,vgg_base.output_shape,vgg_model.input_shape,vgg_model.output_shape
# Out:
# ((None, 150, 150, 3), (None, 4, 4, 512), (None, 150, 150, 3), (None, 8192))

# %% [markdown]
# ## VGG_model (base) for feature extraction and New Head for classifier

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential
from tensorflow.keras import optimizers

input_shape = vgg_model.output_shape[1]

model_head = Sequential([
                     InputLayer(input_shape=(input_shape,),name="input layer")
                    ,Dense(512, activation='relu', input_dim=input_shape)
                    ,Dropout(0.3)
                    ,Dense(512, activation='relu')
                    ,Dropout(0.3)
                    ,Dense(1, activation='sigmoid')
])

model_head.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['binary_accuracy'])

model_head.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,457,985
# Trainable params: 4,457,985
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
model.input_shape,model.output_shape
plot_model(model_head,to_file="../models/new_head_model.png",show_shapes=True, 
                 show_layer_names=True, rankdir='TB',dpi=90)

# %%
history = model.fit(x=train_features_vgg, y=train_labels_enc,
                    validation_data=(validation_features_vgg, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=30,
                    verbose=1)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 1s 9ms/step - loss: 4.3348e-07 - binary_accuracy: 1.0000 - val_loss: 1.2751 - val_binary_accuracy: 0.9010
# Epoch 2/30
# 100/100 [==============================] - 1s 7ms/step - loss: 1.1409e-05 - binary_accuracy: 1.0000 - val_loss: 1.3209 - val_binary_accuracy: 0.9010
# Epoch 3/30
# 100/100 [==============================] - 1s 8ms/step - loss: 5.9074e-04 - binary_accuracy: 0.9997 - val_loss: 1.3487 - val_binary_accuracy: 0.9000
# Epoch 4/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0041 - binary_accuracy: 0.9990 - val_loss: 1.4214 - val_binary_accuracy: 0.8980
# Epoch 5/30
# 100/100 [==============================] - 1s 7ms/step - loss: 8.2327e-05 - binary_accuracy: 1.0000 - val_loss: 1.6326 - val_binary_accuracy: 0.8870
# Epoch 6/30
# 100/100 [==============================] - 1s 8ms/step - loss: 6.6373e-05 - binary_accuracy: 1.0000 - val_loss: 1.2608 - val_binary_accuracy: 0.9020
# Epoch 7/30
# 100/100 [==============================] - 1s 7ms/step - loss: 8.2744e-06 - binary_accuracy: 1.0000 - val_loss: 1.3793 - val_binary_accuracy: 0.9040
# Epoch 8/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0049 - binary_accuracy: 0.9983 - val_loss: 1.4527 - val_binary_accuracy: 0.8970
# Epoch 9/30
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8289e-06 - binary_accuracy: 1.0000 - val_loss: 1.3972 - val_binary_accuracy: 0.8990
# Epoch 10/30
# 100/100 [==============================] - 1s 7ms/step - loss: 5.3838e-08 - binary_accuracy: 1.0000 - val_loss: 1.5236 - val_binary_accuracy: 0.8960
# Epoch 11/30
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4983e-04 - binary_accuracy: 1.0000 - val_loss: 1.5288 - val_binary_accuracy: 0.8980
# Epoch 12/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0039 - binary_accuracy: 0.9993 - val_loss: 1.4152 - val_binary_accuracy: 0.8980
# Epoch 13/30
# 100/100 [==============================] - 1s 7ms/step - loss: 1.3113e-07 - binary_accuracy: 1.0000 - val_loss: 1.6042 - val_binary_accuracy: 0.8940
# Epoch 14/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0051 - binary_accuracy: 0.9987 - val_loss: 1.3656 - val_binary_accuracy: 0.9020
# Epoch 15/30
# 100/100 [==============================] - 1s 7ms/step - loss: 1.4310e-07 - binary_accuracy: 1.0000 - val_loss: 1.3744 - val_binary_accuracy: 0.9020
# Epoch 16/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0038 - binary_accuracy: 0.9987 - val_loss: 1.3648 - val_binary_accuracy: 0.8960
# Epoch 17/30
# 100/100 [==============================] - 1s 8ms/step - loss: 1.4054e-07 - binary_accuracy: 1.0000 - val_loss: 1.4021 - val_binary_accuracy: 0.9000
# Epoch 18/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0017 - binary_accuracy: 0.9997 - val_loss: 1.4248 - val_binary_accuracy: 0.9000
# Epoch 19/30
# 100/100 [==============================] - 1s 7ms/step - loss: 1.4432e-04 - binary_accuracy: 1.0000 - val_loss: 1.5023 - val_binary_accuracy: 0.8960
# Epoch 20/30
# 100/100 [==============================] - 1s 7ms/step - loss: 6.5163e-05 - binary_accuracy: 1.0000 - val_loss: 1.4862 - val_binary_accuracy: 0.9010
# Epoch 21/30
# 100/100 [==============================] - 1s 8ms/step - loss: 2.1132e-07 - binary_accuracy: 1.0000 - val_loss: 1.4833 - val_binary_accuracy: 0.9010
# Epoch 22/30
# 100/100 [==============================] - 1s 8ms/step - loss: 4.4805e-06 - binary_accuracy: 1.0000 - val_loss: 1.5200 - val_binary_accuracy: 0.9000
# Epoch 23/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0013 - binary_accuracy: 0.9997 - val_loss: 1.4348 - val_binary_accuracy: 0.8980
# Epoch 24/30
# 100/100 [==============================] - 1s 7ms/step - loss: 6.2356e-04 - binary_accuracy: 0.9997 - val_loss: 1.3920 - val_binary_accuracy: 0.9030
# Epoch 25/30
# 100/100 [==============================] - 1s 7ms/step - loss: 1.2616e-06 - binary_accuracy: 1.0000 - val_loss: 1.4308 - val_binary_accuracy: 0.8980
# Epoch 26/30
# 100/100 [==============================] - 1s 7ms/step - loss: 7.8666e-05 - binary_accuracy: 1.0000 - val_loss: 1.4273 - val_binary_accuracy: 0.9000
# Epoch 27/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - binary_accuracy: 0.9990 - val_loss: 1.4448 - val_binary_accuracy: 0.8990
# Epoch 28/30
# 100/100 [==============================] - 1s 8ms/step - loss: 2.1880e-07 - binary_accuracy: 1.0000 - val_loss: 1.4422 - val_binary_accuracy: 0.8970
# Epoch 29/30
# 100/100 [==============================] - 1s 8ms/step - loss: 6.5665e-05 - binary_accuracy: 1.0000 - val_loss: 1.5164 - val_binary_accuracy: 0.9040
# Epoch 30/30
# 100/100 [==============================] - 1s 8ms/step - loss: 4.9565e-07 - binary_accuracy: 1.0000 - val_loss: 1.5302 - val_binary_accuracy: 0.8990

# %%
pd.DataFrame(history.history)
# Out:
#             loss  binary_accuracy  val_loss  val_binary_accuracy
# 0   4.334758e-07  1.000000         1.275059  0.901
# 1   1.140867e-05  1.000000         1.320882  0.901
# 2   5.907424e-04  0.999667         1.348727  0.900
# 3   4.119686e-03  0.999000         1.421397  0.898
# 4   8.232656e-05  1.000000         1.632573  0.887
# 5   6.637337e-05  1.000000         1.260785  0.902
# 6   8.274405e-06  1.000000         1.379308  0.904
# 7   4.928015e-03  0.998333         1.452686  0.897
# 8   1.828851e-06  1.000000         1.397170  0.899
# 9   5.383790e-08  1.000000         1.523610  0.896
# 10  2.498346e-04  1.000000         1.528759  0.898
# 11  3.860939e-03  0.999333         1.415193  0.898
# 12  1.311287e-07  1.000000         1.604180  0.894
# 13  5.084794e-03  0.998667         1.365560  0.902
# 14  1.431044e-07  1.000000         1.374350  0.902
# 15  3.792470e-03  0.998667         1.364774  0.896
# 16  1.405353e-07  1.000000         1.402070  0.900
# 17  1.665930e-03  0.999667         1.424798  0.900
# 18  1.443226e-04  1.000000         1.502282  0.896
# 19  6.516318e-05  1.000000         1.486206  0.901
# 20  2.113208e-07  1.000000         1.483265  0.901
# 21  4.480468e-06  1.000000         1.519971  0.900
# 22  1.290166e-03  0.999667         1.434763  0.898
# 23  6.235600e-04  0.999667         1.392025  0.903
# 24  1.261615e-06  1.000000         1.430768  0.898
# 25  7.866598e-05  1.000000         1.427325  0.900
# 26  1.200278e-03  0.999000         1.444825  0.899
# 27  2.187954e-07  1.000000         1.442155  0.897
# 28  6.566544e-05  1.000000         1.516351  0.904
# 29  4.956509e-07  1.000000         1.530195  0.899

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) Performans', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['binary_accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_binary_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('../models/cats_dogs_vggbase_newHead_model.h5')

# %% [markdown]
# ## İmage Data Genarator for overfitting

# %%
train_datagen = ImageDataGenerator(
                                    rescale=1./255, zoom_range=0.2, rotation_range=30,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### **lets see images how to transformed  from image data generator**

# %%
img_id = 1502
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
 pd.DataFrame(cat).shape

# %%
pd.DataFrame(cat[0]).shape
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])
# (2, 1)

# %%
pd.DataFrame(cat[0])[0][0].shape
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])
# (1, 150, 150, 3)

# %%
img_id = 1500
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['dog', 'dog', 'dog', 'dog', 'dog']

# %%
model2 = Sequential([
                  vgg_model
                  ,Dense(512, activation='relu', input_dim=input_shape)
                  ,Dropout(0.3)
                  ,Dense(512, activation='relu')
                  ,Dropout(0.3)
                  ,Dense(1, activation='sigmoid')
])

model2.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=2e-5),
              metrics=['binary_accuracy'])

model2.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_2 (Functional)         (None, 8192)              14714688
# _________________________________________________________________
# dense_33 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 19,172,673
# Trainable params: 4,457,985
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history2=model2.fit(train_generator
           ,epochs=30,verbose=1,
           steps_per_epoch=100,
           validation_data=val_generator)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 27s 267ms/step - loss: 0.2767 - binary_accuracy: 0.8847 - val_loss: 0.2351 - val_binary_accuracy: 0.9050
# Epoch 2/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.2968 - binary_accuracy: 0.8673 - val_loss: 0.2316 - val_binary_accuracy: 0.9090
# Epoch 3/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2957 - binary_accuracy: 0.8740 - val_loss: 0.2329 - val_binary_accuracy: 0.9070
# Epoch 4/30
# 100/100 [==============================] - 27s 268ms/step - loss: 0.2817 - binary_accuracy: 0.8817 - val_loss: 0.2327 - val_binary_accuracy: 0.9080
# Epoch 5/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2808 - binary_accuracy: 0.8820 - val_loss: 0.2321 - val_binary_accuracy: 0.9040
# Epoch 6/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2921 - binary_accuracy: 0.8680 - val_loss: 0.2434 - val_binary_accuracy: 0.8990
# Epoch 7/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2814 - binary_accuracy: 0.8787 - val_loss: 0.2344 - val_binary_accuracy: 0.9030
# Epoch 8/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2798 - binary_accuracy: 0.8783 - val_loss: 0.2331 - val_binary_accuracy: 0.9040
# Epoch 9/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2646 - binary_accuracy: 0.8837 - val_loss: 0.2370 - val_binary_accuracy: 0.9060
# Epoch 10/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2760 - binary_accuracy: 0.8823 - val_loss: 0.2342 - val_binary_accuracy: 0.9060
# Epoch 11/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2763 - binary_accuracy: 0.8780 - val_loss: 0.2385 - val_binary_accuracy: 0.9010
# Epoch 12/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2694 - binary_accuracy: 0.8777 - val_loss: 0.2312 - val_binary_accuracy: 0.9090
# Epoch 13/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2697 - binary_accuracy: 0.8887 - val_loss: 0.2385 - val_binary_accuracy: 0.9020
# Epoch 14/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2707 - binary_accuracy: 0.8823 - val_loss: 0.2277 - val_binary_accuracy: 0.9060
# Epoch 15/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2611 - binary_accuracy: 0.8870 - val_loss: 0.2378 - val_binary_accuracy: 0.9070
# Epoch 16/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2557 - binary_accuracy: 0.8963 - val_loss: 0.2309 - val_binary_accuracy: 0.9120
# Epoch 17/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2589 - binary_accuracy: 0.8923 - val_loss: 0.2301 - val_binary_accuracy: 0.9080
# Epoch 18/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2456 - binary_accuracy: 0.9027 - val_loss: 0.2292 - val_binary_accuracy: 0.9080
# Epoch 19/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2573 - binary_accuracy: 0.8943 - val_loss: 0.2287 - val_binary_accuracy: 0.9110
# Epoch 20/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2724 - binary_accuracy: 0.8823 - val_loss: 0.2331 - val_binary_accuracy: 0.9120
# Epoch 21/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2521 - binary_accuracy: 0.9020 - val_loss: 0.2444 - val_binary_accuracy: 0.9070
# Epoch 22/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.2688 - binary_accuracy: 0.8907 - val_loss: 0.2318 - val_binary_accuracy: 0.9100
# Epoch 23/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2525 - binary_accuracy: 0.9027 - val_loss: 0.2325 - val_binary_accuracy: 0.9120
# Epoch 24/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.2424 - binary_accuracy: 0.8977 - val_loss: 0.2371 - val_binary_accuracy: 0.9100
# Epoch 25/30
# 100/100 [==============================] - 27s 271ms/step - loss: 0.2557 - binary_accuracy: 0.8903 - val_loss: 0.2289 - val_binary_accuracy: 0.9120
# Epoch 26/30
# 100/100 [==============================] - 27s 269ms/step - loss: 0.2500 - binary_accuracy: 0.8877 - val_loss: 0.2288 - val_binary_accuracy: 0.9120
# Epoch 27/30
# 100/100 [==============================] - 27s 272ms/step - loss: 0.2567 - binary_accuracy: 0.8907 - val_loss: 0.2290 - val_binary_accuracy: 0.9080
# Epoch 28/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2598 - binary_accuracy: 0.8870 - val_loss: 0.2273 - val_binary_accuracy: 0.9090
# Epoch 29/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2578 - binary_accuracy: 0.8943 - val_loss: 0.2300 - val_binary_accuracy: 0.9060
# Epoch 30/30
# 100/100 [==============================] - 27s 270ms/step - loss: 0.2450 - binary_accuracy: 0.8943 - val_loss: 0.2294 - val_binary_accuracy: 0.9060

# %%
pd.DataFrame(history2.history)
# Out:
#         loss  binary_accuracy  val_loss  val_binary_accuracy
# 0   0.276725  0.884667         0.235104  0.905
# 1   0.296767  0.867333         0.231632  0.909
# 2   0.295674  0.874000         0.232876  0.907
# 3   0.281665  0.881667         0.232742  0.908
# 4   0.280835  0.882000         0.232120  0.904
# 5   0.292091  0.868000         0.243407  0.899
# 6   0.281422  0.878667         0.234375  0.903
# 7   0.279794  0.878333         0.233146  0.904
# 8   0.264639  0.883667         0.237002  0.906
# 9   0.276012  0.882333         0.234189  0.906
# 10  0.276304  0.878000         0.238488  0.901
# 11  0.269393  0.877667         0.231236  0.909
# 12  0.269660  0.888667         0.238493  0.902
# 13  0.270722  0.882333         0.227685  0.906
# 14  0.261104  0.887000         0.237848  0.907
# 15  0.255668  0.896333         0.230920  0.912
# 16  0.258948  0.892333         0.230064  0.908
# 17  0.245594  0.902667         0.229216  0.908
# 18  0.257252  0.894333         0.228699  0.911
# 19  0.272432  0.882333         0.233102  0.912
# 20  0.252094  0.902000         0.244377  0.907
# 21  0.268789  0.890667         0.231845  0.910
# 22  0.252528  0.902667         0.232502  0.912
# 23  0.242388  0.897667         0.237126  0.910
# 24  0.255734  0.890333         0.228925  0.912
# 25  0.249977  0.887667         0.228755  0.912
# 26  0.256701  0.890667         0.229019  0.908
# 27  0.259805  0.887000         0.227281  0.909
# 28  0.257821  0.894333         0.230032  0.906
# 29  0.245007  0.894333         0.229431  0.906

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Pre-trained CNN (Transfer Learning) with Image Augmentation Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history2.history['binary_accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history2.history['val_binary_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history2.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history2.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('../models/cats_dogs_tlearn_img_aug_cnn.h5')

# %% [markdown]
# ## ** Fine Tunnig With İmage Data Augmantion for Owerfitting**

# %%
vgg_model.trainable = True

set_trainable = False
for layer in vgg_model.layers:
    if layer.name in ['block5_conv1', 'block4_conv1']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
print("Trainable layers:", len(vgg_model.trainable_weights))
# Out:
# Trainable layers: 12

# %%
print("non-Trainable layers:", len(vgg_model.non_trainable_weights))
# Out:
# non-Trainable layers: 14

# %%
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                         Layer Type  ... Layer Trainable
# 0   <keras.engine.input_layer.InputLayer object at 0x7f7b8a9467d0>  ...           False
# 1     <keras.layers.convolutional.Conv2D object at 0x7f7b8a97eed0>  ...           False
# 2     <keras.layers.convolutional.Conv2D object at 0x7f7b8a91c990>  ...           False
# 3     <keras.layers.pooling.MaxPooling2D object at 0x7f7b8a8a1cd0>  ...           False
# 4     <keras.layers.convolutional.Conv2D object at 0x7f7b800e8510>  ...           False
# 5     <keras.layers.convolutional.Conv2D object at 0x7f7b800f2150>  ...           False
# 6     <keras.layers.pooling.MaxPooling2D object at 0x7f7b800e8110>  ...           False
# 7     <keras.layers.convolutional.Conv2D object at 0x7f7b800f4c90>  ...           False
# 8     <keras.layers.convolutional.Conv2D object at 0x7f7b80102350>  ...           False
# 9     <keras.layers.convolutional.Conv2D object at 0x7f7b80107c10>  ...           False
# 10    <keras.layers.pooling.MaxPooling2D object at 0x7f7b800f4fd0>  ...           False
# 11    <keras.layers.convolutional.Conv2D object at 0x7f7b8010f550>  ...            True
# 12    <keras.layers.convolutional.Conv2D object at 0x7f7b80115250>  ...            True
# 13    <keras.layers.convolutional.Conv2D object at 0x7f7b8010f0d0>  ...            True
# 14    <keras.layers.pooling.MaxPooling2D object at 0x7f7b8009f690>  ...            True
# 15    <keras.layers.convolutional.Conv2D object at 0x7f7b800a2d50>  ...            True
# 16    <keras.layers.convolutional.Conv2D object at 0x7f7b800a8850>  ...            True
# 17    <keras.layers.convolutional.Conv2D object at 0x7f7b8009c810>  ...            True
# 18    <keras.layers.pooling.MaxPooling2D object at 0x7f7b800b1f50>  ...            True
# 19            <keras.layers.core.Flatten object at 0x7f7b8002a150>  ...            True
#
# [20 rows x 3 columns]

# %%
train_datagen = ImageDataGenerator(
                                    rescale=1./255, zoom_range=0.2, rotation_range=30,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20)

# %%
model3 = Sequential([
                  vgg_model
                  ,Dense(512, activation='relu', input_dim=input_shape)
                  ,Dropout(0.3)
                  ,Dense(512, activation='relu')
                  ,Dropout(0.3)
                  ,Dense(1, activation='sigmoid')
])

model3.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=2e-5),
              metrics=['binary_accuracy'])

model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 8192)              14714688
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 19,172,673
# Trainable params: 17,437,185
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
histor32=model3.fit(train_generator
           ,epochs=30,verbose=1,
           steps_per_epoch=100,
           validation_data=val_generator)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 42s 339ms/step - loss: 0.4943 - binary_accuracy: 0.7490 - val_loss: 0.2755 - val_binary_accuracy: 0.8900
# Epoch 2/30
# 100/100 [==============================] - 31s 305ms/step - loss: 0.3270 - binary_accuracy: 0.8640 - val_loss: 0.1987 - val_binary_accuracy: 0.9240
# Epoch 3/30
# 100/100 [==============================] - 31s 306ms/step - loss: 0.2422 - binary_accuracy: 0.9017 - val_loss: 0.1961 - val_binary_accuracy: 0.9290
# Epoch 4/30
# 100/100 [==============================] - 31s 306ms/step - loss: 0.2190 - binary_accuracy: 0.9137 - val_loss: 0.1635 - val_binary_accuracy: 0.9410
# Epoch 5/30
# 100/100 [==============================] - 31s 305ms/step - loss: 0.1891 - binary_accuracy: 0.9253 - val_loss: 0.2394 - val_binary_accuracy: 0.9100
# Epoch 6/30
# 100/100 [==============================] - 31s 306ms/step - loss: 0.1523 - binary_accuracy: 0.9367 - val_loss: 0.2194 - val_binary_accuracy: 0.9390
# Epoch 7/30
# 100/100 [==============================] - 31s 309ms/step - loss: 0.1579 - binary_accuracy: 0.9383 - val_loss: 0.1860 - val_binary_accuracy: 0.9440
# Epoch 8/30
# 100/100 [==============================] - 31s 307ms/step - loss: 0.1366 - binary_accuracy: 0.9457 - val_loss: 0.1589 - val_binary_accuracy: 0.9520
# Epoch 9/30
# 100/100 [==============================] - 31s 306ms/step - loss: 0.1102 - binary_accuracy: 0.9580 - val_loss: 0.1900 - val_binary_accuracy: 0.9460
# Epoch 10/30
# 100/100 [==============================] - 31s 307ms/step - loss: 0.1113 - binary_accuracy: 0.9547 - val_loss: 0.1956 - val_binary_accuracy: 0.9490
# Epoch 11/30
# 100/100 [==============================] - 30s 303ms/step - loss: 0.1085 - binary_accuracy: 0.9643 - val_loss: 0.1848 - val_binary_accuracy: 0.9470
# Epoch 12/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0961 - binary_accuracy: 0.9643 - val_loss: 0.1751 - val_binary_accuracy: 0.9530
# Epoch 13/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0838 - binary_accuracy: 0.9710 - val_loss: 0.2621 - val_binary_accuracy: 0.9350
# Epoch 14/30
# 100/100 [==============================] - 31s 305ms/step - loss: 0.0749 - binary_accuracy: 0.9743 - val_loss: 0.2136 - val_binary_accuracy: 0.9580
# Epoch 15/30
# 100/100 [==============================] - 31s 305ms/step - loss: 0.0732 - binary_accuracy: 0.9733 - val_loss: 0.2393 - val_binary_accuracy: 0.9570
# Epoch 16/30
# 100/100 [==============================] - 31s 309ms/step - loss: 0.0758 - binary_accuracy: 0.9703 - val_loss: 0.3110 - val_binary_accuracy: 0.9290
# Epoch 17/30
# 100/100 [==============================] - 30s 301ms/step - loss: 0.0818 - binary_accuracy: 0.9713 - val_loss: 0.1776 - val_binary_accuracy: 0.9520
# Epoch 18/30
# 100/100 [==============================] - 31s 309ms/step - loss: 0.0683 - binary_accuracy: 0.9760 - val_loss: 0.2273 - val_binary_accuracy: 0.9550
# Epoch 19/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0443 - binary_accuracy: 0.9840 - val_loss: 0.2883 - val_binary_accuracy: 0.9550
# Epoch 20/30
# 100/100 [==============================] - 30s 303ms/step - loss: 0.0621 - binary_accuracy: 0.9793 - val_loss: 0.3861 - val_binary_accuracy: 0.9360
# Epoch 21/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0514 - binary_accuracy: 0.9823 - val_loss: 0.2523 - val_binary_accuracy: 0.9500
# Epoch 22/30
# 100/100 [==============================] - 30s 303ms/step - loss: 0.0393 - binary_accuracy: 0.9843 - val_loss: 0.2052 - val_binary_accuracy: 0.9560
# Epoch 23/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0490 - binary_accuracy: 0.9820 - val_loss: 0.2666 - val_binary_accuracy: 0.9440
# Epoch 24/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0520 - binary_accuracy: 0.9820 - val_loss: 0.2609 - val_binary_accuracy: 0.9530
# Epoch 25/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0523 - binary_accuracy: 0.9857 - val_loss: 0.5011 - val_binary_accuracy: 0.9260
# Epoch 26/30
# 100/100 [==============================] - 30s 302ms/step - loss: 0.0443 - binary_accuracy: 0.9883 - val_loss: 0.2777 - val_binary_accuracy: 0.9550
# Epoch 27/30
# 100/100 [==============================] - 30s 300ms/step - loss: 0.0355 - binary_accuracy: 0.9853 - val_loss: 0.2526 - val_binary_accuracy: 0.9560
# Epoch 28/30
# 100/100 [==============================] - 30s 303ms/step - loss: 0.0349 - binary_accuracy: 0.9880 - val_loss: 0.2922 - val_binary_accuracy: 0.9540
# Epoch 29/30
# 100/100 [==============================] - 30s 301ms/step - loss: 0.0354 - binary_accuracy: 0.9880 - val_loss: 0.3040 - val_binary_accuracy: 0.9500
# Epoch 30/30
# 100/100 [==============================] - 30s 299ms/step - loss: 0.0454 - binary_accuracy: 0.9827 - val_loss: 0.2751 - val_binary_accuracy: 0.9570

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
t = f.suptitle('Pre-trained CNN (Transfer Learning) with Fine-Tuning & Image Augmentation Performance', fontsize=20)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, histor32.history['binary_accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, histor32.history['val_binary_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 101, 10))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, histor32.history['loss'], label='Train Loss')
ax2.plot(epoch_list, histor32.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 101, 10))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model3.save('../models/cats_dogs_tlearn_finetune_img_aug_cnn.h5')
